# %% [markdown]
# <a href="https://colab.research.google.com/github/dookda/cmu_lab_154743/blob/main/python_workshop/python_9_Conditions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# การใช้ IF แบบต่างๆ

# %% [markdown]
# 1. **`if` Statement**

# %%
x = 4

if x > 5:
    print("x is greater than 5")

# %% [markdown]
# 2. **`else` Statement**

# %%
y = 3
if y > 5:
    print("y is greater than 5")
else:
    print("y is not greater than 5")

# %% [markdown]
# 3. **`elif` Statement**

# %%
z = 5
if z > 5:
    print("z is greater than 5")
elif z == 5:
    print("z is equal to 5")
elif z == 6:
    print("z is equal to 5")
else:
    print("z is less than 5")

# %% [markdown]
# 4. **Nested Conditions**

# %%
a = 20
if a > 10:
    print("Above ten,")
    if a > 20:
        print("and also above 20!")
    else:
        print("but not above 20.")
else:
    print("zzz")

# %% [markdown]
# 5. **Conditional Expressions**

# %%
age = 18
status = "teenager" if age < 20 else "adult"
print(status)

# %% [markdown]
# 6. **Logical Operators with Conditions**

# %%
age = 25
if age >= 13 and age <= 19:
    print("The person is a teenager.")
else:
    print("The person is not a teenager.")

# %% [markdown]
# **ช่วยตัดเกรดหน่อย**
# - score >= 80:'A'
# - score >= 70:'B'
# - score >= 60:'C'
# - score >= 50:'D'
# - score < 50: 'F'

# %%
score = 85

if score >= 80:
    # print("A")
