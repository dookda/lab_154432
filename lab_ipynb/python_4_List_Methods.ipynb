# %% [markdown]
# <a href="https://colab.research.google.com/github/dookda/cmu_lab_154743/blob/main/python_workshop/python_4_List_Methods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# List Methods

# %%
# append()
fruits = ['apple', 'banana', 'cherry']
fruits.append('orange')
print(fruits)

# %%
# extend()
more_fruits = ['grape', 'pear']
fruits.extend(more_fruits)
print(fruits)

# %%
# insert()
fruits.insert(1, 'kiwi')
print(fruits)

# %%
# remove()
fruits.remove('banana')
print(fruits)

# %%
# pop()
last_fruit = fruits.pop()
print(last_fruit)  # Output: 'pear'
print(fruits)

# %%
# clear()
fruits.clear()
print(fruits)

# %%
# index()
print(fruits)
index = fruits.index('cherry')
print(index)

# %%
print(fruits)

# %%
# append()
fruits.append('apple')
print(fruits.count('apple'))

# %%
# sort()
numbers = [3, 1, 4, 1, 5, 9, 2, 6]
numbers.sort()
print(numbers)

# %%
name = ["Ole", "Guitar", "Kolic", "flook"]

name.sort()
print(name)

# %%
# reverse()
numbers.reverse()
print(numbers)

# %%
# copy()
numbers_copy = numbers.copy()
print(numbers_copy)

a = numbers
print(a)
