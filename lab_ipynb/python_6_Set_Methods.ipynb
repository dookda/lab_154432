# %% [markdown]
# <a href="https://colab.research.google.com/github/dookda/cmu_lab_154743/blob/main/python_workshop/python_6_Set_Methods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Methods สำหรับข้อมูล Set

# %%
# add()
my_set = {1, 2, 3}
my_set.add(4)
print(my_set)

# %%
# update()
my_set.update([4, 5], {6, 7})
print(my_set)

# %%
# remove()
my_set.remove(1)
print(my_set)

# %%
# discard()
my_set.discard(8)
print(my_set)

# %%
# pop()
print(my_set.pop())

# %%
print(my_set)

# %%
# clear()
my_set.clear()
print(my_set)

# %%
# union()
a = {1, 2, 3}
b = {3, 4, 5}
print(a.union(b))

# %%
# intersection()
print(a.intersection(b))

# %%
# difference()
print(a.difference(b))

# %%
# symmetric_difference()
print(a.symmetric_difference(b))

# %%
# issubset()
c = {1, 2}
print(c.issubset(a))

# %%
# issuperset()
print(a.issuperset(c))

# %%
# isdisjoint()
d = {7, 8}
print(a.isdisjoint(d))
