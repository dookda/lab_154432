# %% [markdown]
# <a href="https://colab.research.google.com/github/dookda/cmu_lab_154743/blob/main/python_workshop/python_12_Modules.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# การใช้คำสั่ง `import`

# %% [markdown]
# 1. **Basic Import**

# %%
import math
print(math.sqrt(25))

# %% [markdown]
# 2. **Importing Specific Functions**

# %%
from math import sqrt
print(sqrt(36))

# %% [markdown]
# 3. **Importing Multiple Functions**

# %%
from math import sqrt, cos, sin, pi

print(sqrt(36)) 
print(cos(36)) 
print(sin(36)) 
print(pi)

# %% [markdown]
# 4. **Importing All Names**

# %%
from math import *
print(sin(3.14159))

# %% [markdown]
# 5. **Renaming Imports**

# %%
import numpy as np
import pandas as pd

array = np.array([1, 2, 3])
data_frame = pd.DataFrame(data=array)

# %% [markdown]
# 6. **Creating Your Own Modules**
#
# - เปิดดูไฟล์ python_12_Modules.py

# %%
import python_12_Modules as my_module

my_module.greet("Nok")  
my_module.farewell("Guitar")
