# %% [markdown]
# <a href="https://colab.research.google.com/github/dookda/cmu_lab_154743/blob/main/python_workshop/python_11_Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# การเขียน Function ใน python จะนำหน้าด้วย `def` โดยมีรูปแบบดังนี้
#
# ```python
# def function_name(parameters):
#     """Docstring (optional but recommended)"""
#     # Code block
#     return result  # optional
# ```
#
# เมื่อ
# - **function_name**: ชื่อ function
# - **parameters**: ตัวแปร หรือ ข้อมูลที่ส่งเข้า function (`optional`)
# - **docstring**: คำอธิบาย function (`optional`)
# - **return**: ส่ง outputs จาก function (`optional`)

# %% [markdown]
# 1. **Simple Function**

# %%
def greet():
    print("Hello, welcome to Python functions!")

# %%
# การเรียกใช้งานฟังก์ชัน
greet()

# %% [markdown]
# 2. **Function with Parameters**

# %%
def greet(name):
    print(f"Hello, {name}! How are you?")

# %%
# การเรียกใช้งานฟังก์ชัน
greet("sakda")

# %% [markdown]
# 3. **Returning Values**

# %%
def cooking(x, y):
    return x + 'ผัด' + y

# %%
result = cooking('ไข่', 'ข้าว' )
print(result)

# %% [markdown]
# 4. **Default Parameter Values**

# %%
def greet(name="Kolic"):
    print(f"Hello, {name}! Welcome aboard.")

# %%
greet()  
greet("Guitar")

# %% [markdown]
# 5. **Keyword Arguments**

# %%
def describe_pet(animal, name):
    print(f"I have a {animal} named {name}.")

describe_pet(name="Harry", animal="hamster")

# %% [markdown]
# 6. **Variable-length Arguments**

# %%
def make_pizza(*toppings):
    print("Making a pizza with the following toppings:")
    for topping in toppings:
        print(f"- {topping}")

make_pizza('pepperoni', 'green peppers', 'extra cheese')

# %%
# kwargs (keyword arguments)
def build_profile(first, last, **user_info):
    user_info['first_name'] = first
    user_info['last_name'] = last
    return user_info

user_profile = build_profile('albert', 'einstein', location='princeton', field='physics')

print(user_profile)
