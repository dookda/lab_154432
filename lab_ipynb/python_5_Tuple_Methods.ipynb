# %% [markdown]
# <a href="https://colab.research.google.com/github/dookda/cmu_lab_154743/blob/main/python_workshop/python_5_Tuple_Methods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Methods สำหรับข้อมูล Tuple
#
# Tuple ไม่สามารถ  เพิ่ม ลบ หรือ เปลี่ยนแปลงได้ นิยมใช้เก็บค่าแบบคงที่ เช่น Pi บัตรประชาชน เลขบัตรเครดิต

# %%
# count()
my_tuple = (1, 2, 3, 4, 3, 2, 1, 2, 3, 4, 5)
print(my_tuple.count(2))

# %%
# index()
print(my_tuple.index(4))

# %%
my_tuple
