# %% [markdown]
# <a href="https://colab.research.google.com/github/dookda/cmu_lab_154743/blob/main/python_workshop/python_2_String_Methods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **String Methods**
#
#
# ตัวอย่างของ method ที่ python มีไว้สำหรับจัดการข้อมูล string

# %%
# capitalize()
greeting = "hello world"
print(greeting.capitalize())

# %%
# upper()
text = "python programming"
print(text.upper())

# %%
# lower()
text = "PYTHON PROGRAMMING"
print(text.lower())

# %%
# strip()
name = "   Alice   "
print(name.strip())

# %%
# split()
data = "apple, banana, cherry"
arr = data.split(", ")

print(arr[1])

# %%
# join()
words = ["Hello", "world"]
print(" ".join(words))

# %%
# replace()
text = "I like cats"
print(text)
print(text.replace("cats", "dogs"))

# %%
# find()
text = "world Hello "
print(text.find("world"))

# %%
# count()
text = "the quick brown fox jumps over the lazy dog"

print(text.count("the"))

# %%
# startswith()
text = "hello world"
print(text.startswith("hello"))

# %%
# endswith()
text = "hello_world.png"
print(text.endswith("jpg"))

# %%
print(name)

# format()
text = "The price of a {0} is {1} dollars."
print(text.format("coffee", 2))

# f-string
name = "NeawNuab"
age = 25
print(f"Hello, my name is {name} and I am {age} years old.")

# % operator
name = "NeawNuab"
age = 25
print("Hello, my name is %s and I am %d years old." % (name, age))
