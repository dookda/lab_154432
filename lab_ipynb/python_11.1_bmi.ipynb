# %% [markdown]
# <a href="https://colab.research.google.com/github/dookda/cmu_lab_154743/blob/main/python_workshop/python_11.1_bmi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **ตัวอย่าง BMI**
#
# การหาค่า bmi
#
# https://www.si.mahidol.ac.th/th/healthdetail.asp?aid=1361

# %%
def bmi(w, h):
    res = int(w) / int(int(h/100) ^2)

    if(res<=18.5):
        return  f'ต่ำกว่าเกณฑ์ ({round(res, 2)})'
    elif(res<=22.9):
        return  f'สมส่วน ({round(res, 2)})'
    elif(res<=24.9):
        return  f'น้ำหนักเกิน ({round(res, 2)})'
    elif(res<=29.9):
        return  f'อวบ ({round(res, 2)})'
    else:
        return  f'อิ่ม ({round(res, 2)})'


w = input("กรอกน้ำหนัก: ")
h = input("กรอกส่วนสูง: ")
a = bmi(int(w), int(h))

print(f'คุณ{a}')
